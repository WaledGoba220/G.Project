# %% [markdown]
# <img src="Secondary-logo-Bright.png"  alt="Pneumonia"
#      title="Pneumonia"/>

# %% [markdown]
# # <div style="color:#fff;display:fill;border-radius:10px;background-color:#566573;text-align:center;letter-spacing:0.1px;overflow:hidden;padding:20px;color:white;overflow:hidden;margin:0;font-size:100%">Pneumonia</div>

# %% [markdown]
# # <span style='color:#2E8BC0'> Dataset </span>
#
# #### The dataset we have is splitted into:
#      - train set
#      - test set
#      - val set
# #### The classes are:
#     - normal images
#     - pneumonia images

# %% [markdown]
# # <span style='color:#2E8BC0'> Import Libraries </span>

# %%
from keras.layers import Input, Lambda, Dense, Flatten
from keras.models import Model
from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
import numpy as np
import pandas as pd
from glob import glob
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
import os
import tensorflow as tf
from keras.utils.vis_utils import plot_model
from IPython.display import Image

# %% [markdown]
# # <span style='color:#2E8BC0'> Collect Info About Data (Data Exploration)</span>

# %%
# ==> Get The Num of normal images and num of virus images ==> 1 step ==> train file

num_normal = os.listdir(r"C:\Users\lenovo\Desktop\Project\Pneumonia Project\chest_xray\train\NORMAL")
num_covid = os.listdir(r"C:\Users\lenovo\Desktop\Project\Pneumonia Project\chest_xray\train\PNEUMONIA") 
train_images = {"PNEUMONIA" : len(num_covid) ,
              "Normal" :len(num_normal)
             }

# %%
train_images
# Out:
# {'PNEUMONIA': 3875, 'Normal': 1341}

# %%
# ==> Get The Num of normal images and num of virus images ==> 2 step ==> test file
num_normal = os.listdir(r"C:\Users\lenovo\Desktop\Project\Pneumonia Project\chest_xray\test\NORMAL")
num_covid = os.listdir(r"C:\Users\lenovo\Desktop\Project\Pneumonia Project\chest_xray\test\PNEUMONIA") 
test_images = {"PNEUMONIA" : len(num_covid) ,
              "Normal" :len(num_normal)
             }

# %%
 test_images
# Out:
# {'PNEUMONIA': 390, 'Normal': 234}

# %%
# ==>  Get The Num of normal images and num of virus images ==> 3 step ==> val file
num_normal = os.listdir(r"C:\Users\lenovo\Desktop\Project\Pneumonia Project\chest_xray\val\NORMAL") 
num_covid = os.listdir(r"C:\Users\lenovo\Desktop\Project\Pneumonia Project\chest_xray\val\PNEUMONIA")
validation_images = {"PNEUMONIA" : len(num_covid) ,
              "Normal" :len(num_normal)
             }

# %%
validation_images
# Out:
# {'PNEUMONIA': 8, 'Normal': 8}

# %% [markdown]
# # <span style='color:#2E8BC0'> Show data distribution  </span>

# %%
plt.figure(figsize=(20,6))

# show the train images (1)
plt.subplot(1,3,1)
plt.title("Train images")
plt.ylabel("Number of images")
plt.xlabel("Class")
plt.bar(x=train_images.keys(),height=train_images.values(),color=["#A93226","#34495E"])

# show the test images (2)
plt.subplot(1,3,2)
plt.title("Test images")
plt.ylabel("Number of images")
plt.xlabel("Class")
plt.bar(x=test_images.keys(),height=test_images.values(),color=["#A93226","#34495E"])

# show the validation images (3)
plt.subplot(1,3,3)
plt.title("Validation images")
plt.ylabel("Number of images")
plt.xlabel("Class")
plt.bar(x=validation_images.keys(),height=validation_images.values(),color=["#A93226","#34495E"])
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# #  <span style='color:#2E8BC0'>Re-sizing Images</span>

# %%
IMAGE_SIZE = (224, 224)

# Default batch size
BATCH_SIZE = 32

# %% [markdown]
# #  <span style='color:#2E8BC0'> Show some images from the data  </span>

# %%
# ==> Make Train Data pipline to collect all data in train in one stream
train_ds = tf.keras.utils.image_dataset_from_directory(
  r"C:\Users\lenovo\Desktop\Project\Pneumonia Project\chest_xray\train",  # ==> Path train File
  seed=123,
  image_size=(256, 256), # ==>  the image output size 
  batch_size=32, 
  shuffle=True # ==> to shuffle the images when feeded to the model
)
# Out:
# Found 5216 files belonging to 2 classes.

# %%
# ==> Make test Data pipline to collect all data in train in one stream
test_ds = tf.keras.utils.image_dataset_from_directory(
  r"C:\Users\lenovo\Desktop\Project\Pneumonia Project\chest_xray\test",  # ==> Path train File
  seed=123,
  image_size=(256, 256), # ==>  the image output size 
  batch_size=32, 
  shuffle=True # ==> to shuffle the images when feeded to the model
)
# Out:
# Found 624 files belonging to 2 classes.

# %%
# ==> get the classes names form the data train
classes=train_ds.class_names 
classes
# Out:
# ['NORMAL', 'PNEUMONIA']

# %%
# ==> get the classes names form the data test
classes=test_ds.class_names 
classes
# Out:
# ['NORMAL', 'PNEUMONIA']

# %%
# ==> show 24 images from the data
plt.figure(figsize=(20,20))
for images, labels in train_ds.take(1) :
    # create a grid of 5x5 images
    for i in range(0,25):
        plt.subplot(5,5,i+1)
        plt.imshow(images[i].numpy().astype("u8"))
        plt.title(classes[labels[i]])
        plt.axis('off')
    # show the plot
    plt.show()
    break

# %% [markdown]
# #  <span style='color:#2E8BC0'> Flow from directory</span>

# %%
input_path = r"C:\Users\lenovo\Desktop\Project\Pneumonia\chest_xray"
train_path=r"C:\Users\lenovo\Desktop\Project\Pneumonia Project\chest_xray\train"
test_path=r"C:\Users\lenovo\Desktop\Project\Pneumonia Project\chest_xray\test"

# %%
# Use the Image Data Generator to import the images from the dataset
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
# Make sure you provide the same target size as initialied for the image size
training_set = train_datagen.flow_from_directory(train_path,
                                                 target_size = (224, 224),
                                                 batch_size = 32,
                                                 class_mode = 'categorical')
test_set = test_datagen.flow_from_directory(test_path,
                                            target_size = (224, 224),
                                            batch_size = 32,
                                            class_mode = 'categorical')
# Out:
# Found 5216 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %% [markdown]
# #  <span style='color:#2E8BC0'>Build Model and Show Model Architecture(VGG16)</span>

# %%
# ==>  using imagenet weights
IMAGE_SIZE = [224, 224]
vgg = VGG16(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)

# %%
for layer in vgg.layers:
    layer.trainable = False
folders = glob(r"C:\Users\lenovo\Desktop\Project\Pneumonia Project\chest_xray\train\*") # ==>getting number of output classes
x = Flatten()(vgg.output) # ==> add more of layers
detection = Dense(len(folders), activation='softmax')(x)

model = Model(inputs=vgg.input, outputs=detection) # ==> # model object craetion to usage

# %% [markdown]
# #  <span style='color:#2E8BC0'> Model Architecture(VGG16)</span>

# %%
# ==> Show the architecture of Technique
plot_model(model, show_shapes=True, show_layer_names=True, to_file='vgg16_model.png')
Image('vgg16_model.png')

# %% [markdown]
# #  <span style='color:#2E8BC0'>Model Structure</span>

# %%
# view the structure of the model
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 2)                 50178
#
# =================================================================
# Total params: 14,764,866
# Trainable params: 50,178
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
# ==> optimization method 
model.compile(
  loss='categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)

# %%
# ==> fit method to fitting the model
r = model.fit_generator(
  training_set,
  validation_data=test_set,
  epochs=5,
  steps_per_epoch=len(training_set),
  validation_steps=len(test_set)
)
# Out:
# Epoch 1/5
# 163/163 [==============================] - 579s 4s/step - loss: 0.2001 - accuracy: 0.9227 - val_loss: 0.2592 - val_accuracy: 0.9103
# Epoch 2/5
# 163/163 [==============================] - 580s 4s/step - loss: 0.1269 - accuracy: 0.9557 - val_loss: 0.2962 - val_accuracy: 0.9119
# Epoch 3/5
# 163/163 [==============================] - 581s 4s/step - loss: 0.1126 - accuracy: 0.9578 - val_loss: 0.2562 - val_accuracy: 0.9247
# Epoch 4/5
# 163/163 [==============================] - 579s 4s/step - loss: 0.1131 - accuracy: 0.9536 - val_loss: 0.2894 - val_accuracy: 0.9022
# Epoch 5/5
# 163/163 [==============================] - 583s 4s/step - loss: 0.1066 - accuracy: 0.9620 - val_loss: 0.2807 - val_accuracy: 0.9199

# %%
# ==> Evaluating the model on train and test
score = model.evaluate(training_set)
# ==> 1) train
print("Train Loss: ", score[0])
print("Train Accuracy: ", score[1])
# ==> 1) test
score = model.evaluate(test_set)
print("\nTest loss: ", score[0])
print("Test Accuracy: ", score[1])
# Out:
# 163/163 [==============================] - 502s 3s/step - loss: 0.0796 - accuracy: 0.9726
# Train Loss:  0.07956419140100479
# Train Accuracy:  0.9725843667984009
# 20/20 [==============================] - 61s 3s/step - loss: 0.2807 - accuracy: 0.9199
#
# Test loss:  0.2807478904724121
# Test Accuracy:  0.9198718070983887

# %% [markdown]
# #  <span style='color:#2E8BC0'>Loss & Accuracy</span>

# %%
plt.style.use("ggplot")
plt.figure(figsize=(18, 8))
# the loss curve
plt.subplot(1, 2, 1)
plt.plot(r.history['loss'], label='train_set')
plt.plot(r.history['val_loss'], label='val_set')
plt.legend()
plt.title('Loss Curve')
# the accuracy curve
plt.subplot(1, 2, 2)
plt.plot(r.history['accuracy'], label='train_set')
plt.plot(r.history['val_accuracy'], label='val_set')
plt.legend()
plt.title('Accuraccy Curve')
# Out:
# Text(0.5, 1.0, 'Accuraccy Curve')

# %% [markdown]
# <img src="x.jpeg"  alt="x"
#      title="x"/>
